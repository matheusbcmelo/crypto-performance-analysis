# %%
# import pandas
import pandas as pd
from pyecharts import options as opts
from pyecharts.charts import Bar, Line
from pyecharts.commons.utils import JsCode

# %%
# import dataframes
avg_df = pd.read_pickle('files\\avg_df.pkl')

# convert timestamp to datetime
avg_df['month'] = avg_df['timestamp'].dt.month

# %%
# 1) Your data
dates = [...]      # list of datetime strings or x-axis labels
values = [...]     # corresponding large numbers

# 2) JS function to abbreviate numbers
abbr_formatter = JsCode("""
function (value) {
    if (value >= 1e12) { return +(value/1e12).toFixed(1) + 'T'; }
    if (value >= 1e9)  { return +(value/1e9).toFixed(1)  + 'B'; }
    if (value >= 1e6)  { return +(value/1e6).toFixed(1)  + 'M'; }
    if (value >= 1e3)  { return +(value/1e3).toFixed(1)  + 'K'; }
    return value;
}
""")

# %%
#%% Creating Jan2025 Normalized Price Data

# Create a copy of the DataFrame to avoid modifying the original
normalized_df_2025 = avg_df.copy()

# Filter data starting from January 2025
start_date = pd.to_datetime('2025-01-01')

# Convert period to timestamp before filtering
normalized_df_2025['timestamp'] = normalized_df_2025['timestamp'].dt.to_timestamp()

normalized_df_2025 = normalized_df_2025[normalized_df_2025['timestamp'] >= start_date]

# Sort by timestamp ascending to get correct base prices
normalized_df_2025 = normalized_df_2025.sort_values(['symbols', 'timestamp'], ascending=[True, True])

# Get the first value for each symbol
base_values = normalized_df_2025.groupby('symbols').first()['average_price']

# Calculate normalized prices so that the starting value is 0 instead of 100
normalized_df_2025['normalized_price'] = normalized_df_2025.apply(
    lambda x: (((x['average_price'] / base_values[x['symbols']]) - 1) * 100).round(1),
    axis=1
)

# Plot average price for each symbol using pyecharts
fig = Line(
    init_opts=opts.InitOpts(
        theme="dark",
        bg_color="rgba(0,0,0,0)",
        width="100%",
        height="535px",  
    )
)

# Define the color mapping for chains
color_map = {
    'BTC': '#FC922F',   # Bitcoin Orange
    'ETH': '#626AFF',  # Ethereum Blue
    'BNB': '#FFCF3D',  # Binance Yellow
    'SOL': '#CF62E7',   # Solana Pink
    'XRP': '#DCDCDC',    # Ripple Grey
    'AVAX': '#FF3A3A',  # Avalanche Red
}

# Prepare x-axis as unique date strings for plotting
x_axis = normalized_df_2025['timestamp'].sort_values().unique()
x_axis_str = [ts.strftime('%Y-%m-%d') for ts in x_axis]
fig.add_xaxis(x_axis_str)

# Add a line for each symbol, hide data labels
for symbol, group in normalized_df_2025.groupby('symbols'):
    group = group.set_index('timestamp')
    y_axis = [group['normalized_price'].get(ts, None) for ts in x_axis]
    fig.add_yaxis(
        symbol, y_axis,
        label_opts=opts.LabelOpts(is_show=False),
        itemstyle_opts=opts.ItemStyleOpts(color=color_map[symbol])
    )

# Add responsive rendering options
fig.set_global_opts(
    title_opts=opts.TitleOpts(title="Investment Simulation", subtitle="Normalized Prices from Jan 2025"),
    tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross",),
    datazoom_opts=opts.DataZoomOpts(type_="slider", range_start=0, range_end=100),
    yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter=abbr_formatter)),
    xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=False)),
    legend_opts=opts.LegendOpts(pos_left="right", is_show=False),
)

# Render for embedding with a template that includes viewport meta tag
fig.render('echarts\\invest_simulator_2025_chart.html', template_name="simple_chart.html")
fig.render_notebook()  # For Jupyter Notebook display
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18472\3181486093.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   base_values = normalized_df_2025.groupby('symbols').first()['average_price']
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18472\3181486093.py:52: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for symbol, group in normalized_df_2025.groupby('symbols'):
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="037a237fd6074669adb344dbf12c3e34" style="width:100%; height:535px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_037a237fd6074669adb344dbf12c3e34 = echarts.init(
#                     document.getElementById('037a237fd6074669adb344dbf12c3e34'), 'dark', {renderer: 'canvas'});
#                 var option_037a237fd6074669adb344dbf12c3e34 = {
#     "backgroundColor": "rgba(0,0,0,0)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "AVAX",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "2025-01-06",
#                     0.0
#                 ],
#                 [
#                     "2025-01-13",
#                     -7.4
#                 ],
#                 [
#                     "2025-01-20",
#                     -7.2
#                 ],
#                 [
#                     "2025-01-27",
#                     -22.9
#                 ],
#                 [
#                     "2025-02-03",
#                     -38.0
#                 ],
#                 [
#                     "2025-02-10",
#                     -36.6
#                 ],
#                 [
#                     "2025-02-17",
#                     -38.6
#                 ],
#                 [
#                     "2025-02-24",
#                     -43.6
#                 ],
#                 [
#                     "2025-03-03",
#                     -46.8
#                 ],
#                 [
#                     "2025-03-10",
#                     -56.4
#                 ],
#                 [
#                     "2025-03-17",
#                     -52.5
#                 ],
#                 [
#                     "2025-03-24",
#                     -47.7
#                 ],
#                 [
#                     "2025-03-31",
#                     -55.9
#                 ],
#                 [
#                     "2025-04-07",
#                     -55.7
#                 ],
#                 [
#                     "2025-04-14",
#                     -51.4
#                 ],
#                 [
#                     "2025-04-21",
#                     -47.2
#                 ],
#                 [
#                     "2025-04-28",
#                     -47.6
#                 ],
#                 [
#                     "2025-05-05",
#                     -44.0
#                 ],
#                 [
#                     "2025-05-12",
#                     -39.9
#                 ],
#                 [
#                     "2025-05-19",
#                     -41.4
#                 ],
#                 [
#                     "2025-05-26",
#                     -45.2
#                 ],
#                 [
#                     "2025-06-02",
#                     -48.5
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "itemStyle": {
#                 "color": "#FF3A3A"
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "BNB",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "2025-01-06",
#                     0.0
#                 ],
#                 [
#                     "2025-01-13",
#                     -2.1
#                 ],
#                 [
#                     "2025-01-20",
#                     -3.2
#                 ],
#                 [
#                     "2025-01-27",
#                     -9.2
#                 ],
#                 [
#                     "2025-02-03",
#                     -19.1
#                 ],
#                 [
#                     "2025-02-10",
#                     -6.5
#                 ],
#                 [
#                     "2025-02-17",
#                     -7.6
#                 ],
#                 [
#                     "2025-02-24",
#                     -14.1
#                 ],
#                 [
#                     "2025-03-03",
#                     -17.5
#                 ],
#                 [
#                     "2025-03-10",
#                     -20.4
#                 ],
#                 [
#                     "2025-03-17",
#                     -12.3
#                 ],
#                 [
#                     "2025-03-24",
#                     -12.8
#                 ],
#                 [
#                     "2025-03-31",
#                     -18.1
#                 ],
#                 [
#                     "2025-04-07",
#                     -21.1
#                 ],
#                 [
#                     "2025-04-14",
#                     -17.5
#                 ],
#                 [
#                     "2025-04-21",
#                     -14.6
#                 ],
#                 [
#                     "2025-04-28",
#                     -15.8
#                 ],
#                 [
#                     "2025-05-05",
#                     -11.1
#                 ],
#                 [
#                     "2025-05-12",
#                     -6.5
#                 ],
#                 [
#                     "2025-05-19",
#                     -6.7
#                 ],
#                 [
#                     "2025-05-26",
#                     -5.4
#                 ],
#                 [
#                     "2025-06-02",
#                     -6.8
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "itemStyle": {
#                 "color": "#FFCF3D"
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "BTC",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "2025-01-06",
#                     0.0
#                 ],
#                 [
#                     "2025-01-13",
#                     0.9
#                 ],
#                 [
#                     "2025-01-20",
#                     7.8
#                 ],
#                 [
#                     "2025-01-27",
#                     4.5
#                 ],
#                 [
#                     "2025-02-03",
#                     -0.1
#                 ],
#                 [
#                     "2025-02-10",

# %%
#%% Creating Jan2024 Normalized Price Data

# Create a copy of the DataFrame to avoid modifying the original
normalized_df_2024 = avg_df.copy()

# Filter data starting from January 2024
start_date_2024 = pd.to_datetime('2024-01-01')

# Convert period to timestamp before filtering
normalized_df_2024['timestamp'] = normalized_df_2024['timestamp'].dt.to_timestamp()

normalized_df_2024 = normalized_df_2024[normalized_df_2024['timestamp'] >= start_date_2024]

# Sort by timestamp ascending to get correct base prices
normalized_df_2024 = normalized_df_2024.sort_values(['symbols', 'timestamp'], ascending=[True, True])

# Get the first value for each symbol
base_values = normalized_df_2024.groupby('symbols').first()['average_price']

# Calculate normalized prices so that the starting value is 0 instead of 100
normalized_df_2024['normalized_price'] = normalized_df_2024.apply(
    lambda x: (((x['average_price'] / base_values[x['symbols']]) - 1) * 100).round(1),
    axis=1
)

# Plot average price for each symbol using pyecharts
fig2024 = Line(
    init_opts=opts.InitOpts(
        theme="dark",
        bg_color="rgba(0,0,0,0)",
        width="100%",
        height="535px",  
    )
)

# Define the color mapping for chains
color_map = {
    'BTC': '#FC922F',   # Bitcoin Orange
    'ETH': '#626AFF',  # Ethereum Blue
    'BNB': '#FFCF3D',  # Binance Yellow
    'SOL': '#CF62E7',   # Solana Pink
    'XRP': '#DCDCDC',    # Ripple Grey
    'AVAX': '#FF3A3A',  # Avalanche Red
}

# Prepare x-axis as unique date strings for plotting
x_axis = normalized_df_2024['timestamp'].sort_values().unique()
x_axis_str = [ts.strftime('%Y-%m-%d') for ts in x_axis]
fig2024.add_xaxis(x_axis_str)

# Add a line for each symbol, hide data labels
for symbol, group in normalized_df_2024.groupby('symbols'):
    group = group.set_index('timestamp')
    y_axis = [group['normalized_price'].get(ts, None) for ts in x_axis]
    fig2024.add_yaxis(
        symbol, y_axis,
        label_opts=opts.LabelOpts(is_show=False),
        itemstyle_opts=opts.ItemStyleOpts(color=color_map[symbol])
    )

# Add responsive rendering options
fig2024.set_global_opts(
    title_opts=opts.TitleOpts(title="Investment Simulation", subtitle="Normalized Prices from Jan 2024"),
    tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross",),
    datazoom_opts=opts.DataZoomOpts(type_="slider", range_start=0, range_end=100),
    yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter=abbr_formatter)),
    xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=False)),
    legend_opts=opts.LegendOpts(pos_left="right", is_show=False),
)

# Render for embedding with a template that includes viewport meta tag
fig2024.render('echarts\\invest_simulator_2024_chart.html', template_name="simple_chart.html")
fig2024.render_notebook()  # For Jupyter Notebook display
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18472\4255476858.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   base_values = normalized_df_2024.groupby('symbols').first()['average_price']
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18472\4255476858.py:52: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for symbol, group in normalized_df_2024.groupby('symbols'):
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4861f581fc8f4ebebe745d717e9f472b" style="width:100%; height:535px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4861f581fc8f4ebebe745d717e9f472b = echarts.init(
#                     document.getElementById('4861f581fc8f4ebebe745d717e9f472b'), 'dark', {renderer: 'canvas'});
#                 var option_4861f581fc8f4ebebe745d717e9f472b = {
#     "backgroundColor": "rgba(0,0,0,0)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "AVAX",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "2024-01-01",
#                     0.0
#                 ],
#                 [
#                     "2024-01-08",
#                     -4.6
#                 ],
#                 [
#                     "2024-01-15",
#                     -11.1
#                 ],
#                 [
#                     "2024-01-22",
#                     -16.4
#                 ],
#                 [
#                     "2024-01-29",
#                     -8.6
#                 ],
#                 [
#                     "2024-02-05",
#                     -2.1
#                 ],
#                 [
#                     "2024-02-12",
#                     7.2
#                 ],
#                 [
#                     "2024-02-19",
#                     -0.9
#                 ],
#                 [
#                     "2024-02-26",
#                     6.0
#                 ],
#                 [
#                     "2024-03-04",
#                     4.6
#                 ],
#                 [
#                     "2024-03-11",
#                     32.7
#                 ],
#                 [
#                     "2024-03-18",
#                     51.4
#                 ],
#                 [
#                     "2024-03-25",
#                     47.1
#                 ],
#                 [
#                     "2024-04-01",
#                     28.0
#                 ],
#                 [
#                     "2024-04-08",
#                     4.6
#                 ],
#                 [
#                     "2024-04-15",
#                     -7.6
#                 ],
#                 [
#                     "2024-04-22",
#                     -4.6
#                 ],
#                 [
#                     "2024-04-29",
#                     -10.7
#                 ],
#                 [
#                     "2024-05-06",
#                     -5.0
#                 ],
#                 [
#                     "2024-05-13",
#                     -9.6
#                 ],
#                 [
#                     "2024-05-20",
#                     0.6
#                 ],
#                 [
#                     "2024-05-27",
#                     -3.6
#                 ],
#                 [
#                     "2024-06-03",
#                     -11.0
#                 ],
#                 [
#                     "2024-06-10",
#                     -17.3
#                 ],
#                 [
#                     "2024-06-17",
#                     -28.8
#                 ],
#                 [
#                     "2024-06-24",
#                     -30.6
#                 ],
#                 [
#                     "2024-07-01",
#                     -32.1
#                 ],
#                 [
#                     "2024-07-08",
#                     -32.1
#                 ],
#                 [
#                     "2024-07-15",
#                     -22.5
#                 ],
#                 [
#                     "2024-07-22",
#                     -22.6
#                 ],
#                 [
#                     "2024-07-29",
#                     -35.4
#                 ],
#                 [
#                     "2024-08-05",
#                     -47.6
#                 ],
#                 [
#                     "2024-08-12",
#                     -45.5
#                 ],
#                 [
#                     "2024-08-19",
#                     -36.8
#                 ],
#                 [
#                     "2024-08-26",
#                     -36.9
#                 ],
#                 [
#                     "2024-09-02",
#                     -42.5
#                 ],
#                 [
#                     "2024-09-09",
#                     -36.6
#                 ],
#                 [
#                     "2024-09-16",
#                     -32.5
#                 ],
#                 [
#                     "2024-09-23",
#                     -25.0
#                 ],
#                 [
#                     "2024-09-30",
#                     -30.7
#                 ],
#                 [
#                     "2024-10-07",
#                     -28.8
#                 ],
#                 [
#                     "2024-10-14",
#                     -25.9
#                 ],
#                 [
#                     "2024-10-21",
#                     -30.3
#                 ],
#                 [
#                     "2024-10-28",
#                     -35.0
#                 ],
#                 [
#                     "2024-11-04",
#                     -27.3
#                 ],
#                 [
#                     "2024-11-11",
#                     -10.8
#                 ],
#                 [
#                     "2024-11-18",
#                     1.4
#                 ],
#                 [
#                     "2024-11-25",
#                     13.0
#                 ],
#                 [
#                     "2024-12-02",
#                     31.8
#                 ],
#                 [
#                     "2024-12-09",
#                     25.2
#                 ],
#                 [
#                     "2024-12-16",
#                     11.9
#                 ],
#                 [
#                     "2024-12-23",
#                     1.4
#                 ],
#                 [
#                     "2024-12-30",
#                     2.0
#                 ],
#                 [
#                     "2025-01-06",
#                     5.3
#                 ],
#                 [
#                     "2025-01-13",
#                     -2.5
#                 ],
#                 [
#                     "2025-01-20",
#                     -2.3
#                 ],
#                 [
#                     "2025-01-27",
#                     -18.8
#                 ],
#                 [
#                     "2025-02-03",
#                     -34.7
#                 ],
#                 [
#                     "2025-02-10",
#                     -33.2
#                 ],
#                 [
#                     "2025-02-17",
#                     -35.3
#                 ],
#                 [
#                     "2025-02-24",
#                     -40.7
#                 ],
#                 [
#                     "2025-03-03",
#                     -43.9
#                 ],
#                 [
#                     "2025-03-10",
#                     -54.1
#                 ],
#                 [
#                     "2025-03-17",
#                     -49.9
#                 ],
#                 [
#                     "2025-03-24",
#                     -44.9
#                 ],
#                 [
#                     "2025-03-31",
#                     -53.5
#                 ],
#                 [
#                     "2025-04-07",
#                     -53.4
#                 ],
#                 [
#                     "2025-04-14",
#                     -48.8
#                 ],
#                 [
#                     "2025-04-21",
#                     -44.4
#                 ],
#                 [
#                     "2025-04-28",
#                     -44.8
#                 ],

# %%
#%% Creating Jan2023 Normalized Price Data

# Create a copy of the DataFrame to avoid modifying the original
normalized_df_2023 = avg_df.copy()

# Filter data starting from January 2023
start_date_2023 = pd.to_datetime('2023-01-01')

# Convert period to timestamp before filtering
normalized_df_2023['timestamp'] = normalized_df_2023['timestamp'].dt.to_timestamp()

normalized_df_2023 = normalized_df_2023[normalized_df_2023['timestamp'] >= start_date_2023]

# Sort by timestamp ascending to get correct base prices
normalized_df_2023 = normalized_df_2023.sort_values(['symbols', 'timestamp'], ascending=[True, True])

# Get the first value for each symbol
base_values = normalized_df_2023.groupby('symbols').first()['average_price']

# Calculate normalized prices so that the starting value is 0 instead of 100
normalized_df_2023['normalized_price'] = normalized_df_2023.apply(
    lambda x: (((x['average_price'] / base_values[x['symbols']]) - 1) * 100).round(1),
    axis=1
)

# Plot average price for each symbol using pyecharts
fig2023 = Line(
    init_opts=opts.InitOpts(
        theme="dark",
        bg_color="rgba(0,0,0,0)",
        width="100%",
        height="535px",  
    )
)

# Define the color mapping for chains
color_map = {
    'BTC': '#FC922F',   # Bitcoin Orange
    'ETH': '#626AFF',  # Ethereum Blue
    'BNB': '#FFCF3D',  # Binance Yellow
    'SOL': '#CF62E7',   # Solana Pink
    'XRP': '#DCDCDC',    # Ripple Grey
    'AVAX': '#FF3A3A',  # Avalanche Red
}

# Prepare x-axis as unique date strings for plotting
x_axis = normalized_df_2023['timestamp'].sort_values().unique()
x_axis_str = [ts.strftime('%Y-%m-%d') for ts in x_axis]
fig2023.add_xaxis(x_axis_str)

# Add a line for each symbol, hide data labels
for symbol, group in normalized_df_2023.groupby('symbols'):
    group = group.set_index('timestamp')
    y_axis = [group['normalized_price'].get(ts, None) for ts in x_axis]
    fig2023.add_yaxis(
        symbol, y_axis,
        label_opts=opts.LabelOpts(is_show=False),
        itemstyle_opts=opts.ItemStyleOpts(color=color_map[symbol])
    )

# Add responsive rendering options
fig2023.set_global_opts(
    title_opts=opts.TitleOpts(title="Investment Simulation", subtitle="Normalized Prices from Jan 2023"),
    tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross",),
    datazoom_opts=opts.DataZoomOpts(type_="slider", range_start=0, range_end=100),
    yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter=abbr_formatter)),
    xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=False)),
    legend_opts=opts.LegendOpts(pos_left="right", is_show=False),
)

# Render for embedding with a template that includes viewport meta tag
fig2023.render('echarts\\invest_simulator_2023_chart.html', template_name="simple_chart.html")
fig2023.render_notebook()  # For Jupyter Notebook display
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18472\3131766918.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   base_values = normalized_df_2023.groupby('symbols').first()['average_price']
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18472\3131766918.py:52: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for symbol, group in normalized_df_2023.groupby('symbols'):
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="36eec6e3c32841298b9342ddbf6f0d98" style="width:100%; height:535px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_36eec6e3c32841298b9342ddbf6f0d98 = echarts.init(
#                     document.getElementById('36eec6e3c32841298b9342ddbf6f0d98'), 'dark', {renderer: 'canvas'});
#                 var option_36eec6e3c32841298b9342ddbf6f0d98 = {
#     "backgroundColor": "rgba(0,0,0,0)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "AVAX",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "2023-01-02",
#                     0.0
#                 ],
#                 [
#                     "2023-01-09",
#                     32.9
#                 ],
#                 [
#                     "2023-01-16",
#                     47.7
#                 ],
#                 [
#                     "2023-01-23",
#                     66.6
#                 ],
#                 [
#                     "2023-01-30",
#                     80.3
#                 ],
#                 [
#                     "2023-02-06",
#                     67.2
#                 ],
#                 [
#                     "2023-02-13",
#                     62.0
#                 ],
#                 [
#                     "2023-02-20",
#                     70.0
#                 ],
#                 [
#                     "2023-02-27",
#                     49.6
#                 ],
#                 [
#                     "2023-03-06",
#                     33.0
#                 ],
#                 [
#                     "2023-03-13",
#                     45.6
#                 ],
#                 [
#                     "2023-03-20",
#                     48.7
#                 ],
#                 [
#                     "2023-03-27",
#                     47.3
#                 ],
#                 [
#                     "2023-04-03",
#                     52.3
#                 ],
#                 [
#                     "2023-04-10",
#                     64.9
#                 ],
#                 [
#                     "2023-04-17",
#                     65.4
#                 ],
#                 [
#                     "2023-04-24",
#                     50.1
#                 ],
#                 [
#                     "2023-05-01",
#                     48.0
#                 ],
#                 [
#                     "2023-05-08",
#                     34.9
#                 ],
#                 [
#                     "2023-05-15",
#                     28.3
#                 ],
#                 [
#                     "2023-05-22",
#                     25.1
#                 ],
#                 [
#                     "2023-05-29",
#                     25.2
#                 ],
#                 [
#                     "2023-06-05",
#                     8.3
#                 ],
#                 [
#                     "2023-06-12",
#                     0.4
#                 ],
#                 [
#                     "2023-06-19",
#                     8.0
#                 ],
#                 [
#                     "2023-06-26",
#                     12.0
#                 ],
#                 [
#                     "2023-07-03",
#                     15.0
#                 ],
#                 [
#                     "2023-07-10",
#                     25.3
#                 ],
#                 [
#                     "2023-07-17",
#                     21.3
#                 ],
#                 [
#                     "2023-07-24",
#                     14.6
#                 ],
#                 [
#                     "2023-07-31",
#                     11.7
#                 ],
#                 [
#                     "2023-08-07",
#                     8.7
#                 ],
#                 [
#                     "2023-08-14",
#                     -2.3
#                 ],
#                 [
#                     "2023-08-21",
#                     -10.5
#                 ],
#                 [
#                     "2023-08-28",
#                     -8.9
#                 ],
#                 [
#                     "2023-09-04",
#                     -15.8
#                 ],
#                 [
#                     "2023-09-11",
#                     -19.1
#                 ],
#                 [
#                     "2023-09-18",
#                     -21.6
#                 ],
#                 [
#                     "2023-09-25",
#                     -19.8
#                 ],
#                 [
#                     "2023-10-02",
#                     -8.7
#                 ],
#                 [
#                     "2023-10-09",
#                     -17.6
#                 ],
#                 [
#                     "2023-10-16",
#                     -18.5
#                 ],
#                 [
#                     "2023-10-23",
#                     -7.3
#                 ],
#                 [
#                     "2023-10-30",
#                     2.4
#                 ],
#                 [
#                     "2023-11-06",
#                     37.6
#                 ],
#                 [
#                     "2023-11-13",
#                     75.0
#                 ],
#                 [
#                     "2023-11-20",
#                     83.3
#                 ],
#                 [
#                     "2023-11-27",
#                     83.5
#                 ],
#                 [
#                     "2023-12-04",
#                     154.6
#                 ],
#                 [
#                     "2023-12-11",
#                     234.5
#                 ],
#                 [
#                     "2023-12-18",
#                     275.9
#                 ],
#                 [
#                     "2023-12-25",
#                     275.7
#                 ],
#                 [
#                     "2024-01-01",
#                     232.6
#                 ],
#                 [
#                     "2024-01-08",
#                     217.2
#                 ],
#                 [
#                     "2024-01-15",
#                     195.7
#                 ],
#                 [
#                     "2024-01-22",
#                     178.1
#                 ],
#                 [
#                     "2024-01-29",
#                     203.9
#                 ],
#                 [
#                     "2024-02-05",
#                     225.6
#                 ],
#                 [
#                     "2024-02-12",
#                     256.4
#                 ],
#                 [
#                     "2024-02-19",
#                     229.5
#                 ],
#                 [
#                     "2024-02-26",
#                     252.5
#                 ],
#                 [
#                     "2024-03-04",
#                     247.8
#                 ],
#                 [
#                     "2024-03-11",
#                     341.2
#                 ],
#                 [
#                     "2024-03-18",
#                     403.5
#                 ],
#                 [
#                     "2024-03-25",
#                     389.1
#                 ],
#                 [
#                     "2024-04-01",
#                     325.7
#                 ],
#                 [
#                     "2024-04-08",
#                     248.0
#                 ],
#                 [
#                     "2024-04-15",
#                     207.3
#                 ],
#                 [
#                     "2024-04-22",
#                     217.4
#                 ],
#                 [
#                     "2024-04-29",
#                     196.9
#                 ],

# %%
#%% Creating Jan2022 Normalized Price Data

# Create a copy of the DataFrame to avoid modifying the original
normalized_df_2022 = avg_df.copy()

# Filter data starting from January 2022
start_date_2022 = pd.to_datetime('2022-01-01')

# Convert period to timestamp before filtering
normalized_df_2022['timestamp'] = normalized_df_2022['timestamp'].dt.to_timestamp()

normalized_df_2022 = normalized_df_2022[normalized_df_2022['timestamp'] >= start_date_2022]

# Sort by timestamp ascending to get correct base prices
normalized_df_2022 = normalized_df_2022.sort_values(['symbols', 'timestamp'], ascending=[True, True])

# Get the first value for each symbol
base_values = normalized_df_2022.groupby('symbols').first()['average_price']

# Calculate normalized prices so that the starting value is 0 instead of 100
normalized_df_2022['normalized_price'] = normalized_df_2022.apply(
    lambda x: (((x['average_price'] / base_values[x['symbols']]) - 1) * 100).round(1),
    axis=1
)

# Plot average price for each symbol using pyecharts
fig2022 = Line(
    init_opts=opts.InitOpts(
        theme="dark",
        bg_color="rgba(0,0,0,0)",
        width="100%",
        height="535px",  
    )
)

# Define the color mapping for chains
color_map = {
    'BTC': '#FC922F',   # Bitcoin Orange
    'ETH': '#626AFF',  # Ethereum Blue
    'BNB': '#FFCF3D',  # Binance Yellow
    'SOL': '#CF62E7',   # Solana Pink
    'XRP': '#DCDCDC',    # Ripple Grey
    'AVAX': '#FF3A3A',  # Avalanche Red
}

# Prepare x-axis as unique date strings for plotting
x_axis = normalized_df_2022['timestamp'].sort_values().unique()
x_axis_str = [ts.strftime('%Y-%m-%d') for ts in x_axis]
fig2022.add_xaxis(x_axis_str)

# Add a line for each symbol, hide data labels
for symbol, group in normalized_df_2022.groupby('symbols'):
    group = group.set_index('timestamp')
    y_axis = [group['normalized_price'].get(ts, None) for ts in x_axis]
    fig2022.add_yaxis(
        symbol, y_axis,
        label_opts=opts.LabelOpts(is_show=False),
        itemstyle_opts=opts.ItemStyleOpts(color=color_map[symbol])
    )

# Add responsive rendering options
fig2022.set_global_opts(
    title_opts=opts.TitleOpts(title="Investment Simulation", subtitle="Normalized Prices from Jan 2022"),
    tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross",),
    datazoom_opts=opts.DataZoomOpts(type_="slider", range_start=0, range_end=100),
    yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter=abbr_formatter)),
    xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=False)),
    legend_opts=opts.LegendOpts(pos_left="right", is_show=False),
)

# Render for embedding with a template that includes viewport meta tag
fig2022.render('echarts\\invest_simulator_2022_chart.html', template_name="simple_chart.html")
fig2022.render_notebook()  # For Jupyter Notebook display
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18472\2319832615.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   base_values = normalized_df_2022.groupby('symbols').first()['average_price']
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18472\2319832615.py:52: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for symbol, group in normalized_df_2022.groupby('symbols'):
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bc45563ecc8a4a759a78214eb70c3a7e" style="width:100%; height:535px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bc45563ecc8a4a759a78214eb70c3a7e = echarts.init(
#                     document.getElementById('bc45563ecc8a4a759a78214eb70c3a7e'), 'dark', {renderer: 'canvas'});
#                 var option_bc45563ecc8a4a759a78214eb70c3a7e = {
#     "backgroundColor": "rgba(0,0,0,0)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "AVAX",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "2022-01-03",
#                     0.0
#                 ],
#                 [
#                     "2022-01-10",
#                     -8.3
#                 ],
#                 [
#                     "2022-01-17",
#                     -24.8
#                 ],
#                 [
#                     "2022-01-24",
#                     -33.4
#                 ],
#                 [
#                     "2022-01-31",
#                     -24.9
#                 ],
#                 [
#                     "2022-02-07",
#                     -10.5
#                 ],
#                 [
#                     "2022-02-14",
#                     -9.5
#                 ],
#                 [
#                     "2022-02-21",
#                     -22.7
#                 ],
#                 [
#                     "2022-02-28",
#                     -15.9
#                 ],
#                 [
#                     "2022-03-07",
#                     -23.6
#                 ],
#                 [
#                     "2022-03-14",
#                     -18.3
#                 ],
#                 [
#                     "2022-03-21",
#                     -9.6
#                 ],
#                 [
#                     "2022-03-28",
#                     -0.6
#                 ],
#                 [
#                     "2022-04-04",
#                     -7.5
#                 ],
#                 [
#                     "2022-04-11",
#                     -20.0
#                 ],
#                 [
#                     "2022-04-18",
#                     -21.2
#                 ],
#                 [
#                     "2022-04-25",
#                     -33.7
#                 ],
#                 [
#                     "2022-05-02",
#                     -37.8
#                 ],
#                 [
#                     "2022-05-09",
#                     -60.4
#                 ],
#                 [
#                     "2022-05-16",
#                     -66.9
#                 ],
#                 [
#                     "2022-05-23",
#                     -71.8
#                 ],
#                 [
#                     "2022-05-30",
#                     -73.5
#                 ],
#                 [
#                     "2022-06-06",
#                     -76.7
#                 ],
#                 [
#                     "2022-06-13",
#                     -83.2
#                 ],
#                 [
#                     "2022-06-20",
#                     -80.7
#                 ],
#                 [
#                     "2022-06-27",
#                     -80.8
#                 ],
#                 [
#                     "2022-07-04",
#                     -80.6
#                 ],
#                 [
#                     "2022-07-11",
#                     -80.1
#                 ],
#                 [
#                     "2022-07-18",
#                     -75.7
#                 ],
#                 [
#                     "2022-07-25",
#                     -76.5
#                 ],
#                 [
#                     "2022-08-01",
#                     -73.8
#                 ],
#                 [
#                     "2022-08-08",
#                     -70.3
#                 ],
#                 [
#                     "2022-08-15",
#                     -73.8
#                 ],
#                 [
#                     "2022-08-22",
#                     -78.4
#                 ],
#                 [
#                     "2022-08-29",
#                     -80.3
#                 ],
#                 [
#                     "2022-09-05",
#                     -79.8
#                 ],
#                 [
#                     "2022-09-12",
#                     -80.2
#                 ],
#                 [
#                     "2022-09-19",
#                     -82.2
#                 ],
#                 [
#                     "2022-09-26",
#                     -81.9
#                 ],
#                 [
#                     "2022-10-03",
#                     -82.4
#                 ],
#                 [
#                     "2022-10-10",
#                     -83.6
#                 ],
#                 [
#                     "2022-10-17",
#                     -84.0
#                 ],
#                 [
#                     "2022-10-24",
#                     -82.2
#                 ],
#                 [
#                     "2022-10-31",
#                     -80.3
#                 ],
#                 [
#                     "2022-11-07",
#                     -84.0
#                 ],
#                 [
#                     "2022-11-14",
#                     -86.5
#                 ],
#                 [
#                     "2022-11-21",
#                     -87.2
#                 ],
#                 [
#                     "2022-11-28",
#                     -86.6
#                 ],
#                 [
#                     "2022-12-05",
#                     -85.9
#                 ],
#                 [
#                     "2022-12-12",
#                     -86.6
#                 ],
#                 [
#                     "2022-12-19",
#                     -88.0
#                 ],
#                 [
#                     "2022-12-26",
#                     -88.4
#                 ],
#                 [
#                     "2023-01-02",
#                     -88.1
#                 ],
#                 [
#                     "2023-01-09",
#                     -84.2
#                 ],
#                 [
#                     "2023-01-16",
#                     -82.4
#                 ],
#                 [
#                     "2023-01-23",
#                     -80.2
#                 ],
#                 [
#                     "2023-01-30",
#                     -78.5
#                 ],
#                 [
#                     "2023-02-06",
#                     -80.1
#                 ],
#                 [
#                     "2023-02-13",
#                     -80.7
#                 ],
#                 [
#                     "2023-02-20",
#                     -79.8
#                 ],
#                 [
#                     "2023-02-27",
#                     -82.2
#                 ],
#                 [
#                     "2023-03-06",
#                     -84.2
#                 ],
#                 [
#                     "2023-03-13",
#                     -82.7
#                 ],
#                 [
#                     "2023-03-20",
#                     -82.3
#                 ],
#                 [
#                     "2023-03-27",
#                     -82.5
#                 ],
#                 [
#                     "2023-04-03",
#                     -81.9
#                 ],
#                 [
#                     "2023-04-10",
#                     -80.4
#                 ],
#                 [
#                     "2023-04-17",
#                     -80.3
#                 ],
#                 [
#                     "2023-04-24",
#                     -82.1
#                 ],
#                 [
#                     "2023-05-01",
